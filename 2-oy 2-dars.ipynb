# %%
import pandas as pd

# %%
df=pd.read_csv('housing_price_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SquareFeet    49995 non-null  float64
#  1   Bedrooms      49994 non-null  float64
#  2   Bathrooms     49993 non-null  float64
#  3   Neighborhood  49996 non-null  object
#  4   YearBuilt     49995 non-null  float64
#  5   Price         49994 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt        Price
# 0      2126.0       4.0        1.0        Rural     1969.0  215355.2836
# 1      2459.0       3.0        2.0        Rural     1980.0  195014.2216
# 2      1860.0       2.0        1.0       Suburb     1970.0  306891.0121
# 3      2294.0       2.0        1.0        Urban     1996.0  206786.7872
# 4      2130.0       5.0        2.0       Suburb     2001.0  272436.2391

# %% [markdown]
# # har bir feet uchun narxni kursatuvchi yangi ustun hosil qilamiz:

# %%
df['price_per_feet']=df['Price']/df['SquareFeet']

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt        Price  \
# 0      2126.0       4.0        1.0        Rural     1969.0  215355.2836
# 1      2459.0       3.0        2.0        Rural     1980.0  195014.2216
# 2      1860.0       2.0        1.0       Suburb     1970.0  306891.0121
# 3      2294.0       2.0        1.0        Urban     1996.0  206786.7872
# 4      2130.0       5.0        2.0       Suburb     2001.0  272436.2391
#
#    price_per_feet
# 0      101.295994
# 1       79.306312
# 2      164.995168
# 3       90.142453
# 4      127.904338

# %% [markdown]
# # yangi dataset yuklab olamiz

# %%
df=pd.read_csv('Personal_Finance_Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   object
#  1   Transaction Description  1500 non-null   object
#  2   Category                 1500 non-null   object
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 58.7+ KB

# %%
df.head()
# Out:
#          Date                   Transaction Description      Category  \
# 0  2020-01-02                               Score each.  Food & Drink
# 1  2020-01-02                       Quality throughout.     Utilities
# 2  2020-01-04        Instead ahead despite measure ago.          Rent
# 3  2020-01-05  Information last everything thank serve.    Investment
# 4  2020-01-13              Future choice whatever from.  Food & Drink
#
#     Amount     Type
# 0  1485.69  Expense
# 1  1475.58  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense

# %% [markdown]
# # date ustunini yil, oy, kunga ajratib olamiz

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   datetime64[ns]
#  1   Transaction Description  1500 non-null   object
#  2   Category                 1500 non-null   object
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 58.7+ KB

# %%
df['Yil']=df['Date'].dt.year
df['Oy']=df['Date'].dt.month
df['Kun']=df['Date'].dt.day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   datetime64[ns]
#  1   Transaction Description  1500 non-null   object
#  2   Category                 1500 non-null   object
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   object
#  5   Yil                      1500 non-null   int32
#  6   Oy                       1500 non-null   int32
#  7   Kun                      1500 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(3), object(3)
# memory usage: 76.3+ KB

# %% [markdown]
# # original date ustunini tashlab yubormaiz

# %%
df.drop('Date', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Transaction Description  1500 non-null   object
#  1   Category                 1500 non-null   object
#  2   Amount                   1500 non-null   float64
#  3   Type                     1500 non-null   object
#  4   Yil                      1500 non-null   int32
#  5   Oy                       1500 non-null   int32
#  6   Kun                      1500 non-null   int32
# dtypes: float64(1), int32(3), object(3)
# memory usage: 64.6+ KB

# %% [markdown]
# # yana boshqa dataset yuklab olamiz

# %%
df=pd.read_csv('corporate_stress_dataset.csv')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_9536\4169159405.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('corporate_stress_dataset.csv')

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                9.0                    2                5
# ...

# %% [markdown]
# # har haftalik maosh uchun yangi ustun hosil qilamiz

# %%
df['haftalik_maosh']=df['Monthly_Salary_INR']/4

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Family_Support_Level Job_Satisfaction Performance_Rating  \
# 0         True  ...                     2                5               10.0
# ...

# %% [markdown]
# # har soatiga necci puldan topayotganini kursatuvchi ustun qushamiz

# %%
df['soatlik_maosh']=df['haftalik_maosh']/df['Working_Hours_per_Week']

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Job_Satisfaction Performance_Rating Team_Size  \
# 0         True  ...                 5               10.0        38
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  object
#  3   Marital_Status                    50000 non-null  object
#  4   Job_Role                          49999 non-null  object
#  5   Experience_Years                  50000 non-null  int64
#  6   Monthly_Salary_INR                50000 non-null  float64
#  7   Working_Hours_per_Week            50000 non-null  int64
#  8   Commute_Time_Hours                49999 non-null  float64
#  9   Remote_Work                       50000 non-null  bool
#  10  Stress_Level                      49999 non-null  float64
# ...

# %% [markdown]
# # yana boshqa dataset yuklab olamiz

# %%
df=pd.read_csv('Train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10995 non-null  object
#  3   Customer_care_calls  10995 non-null  float64
#  4   Customer_rating      10997 non-null  float64
#  5   Cost_of_the_Product  10996 non-null  float64
#  6   Prior_purchases      10996 non-null  float64
#  7   Product_importance   10996 non-null  object
#  8   Gender               10996 non-null  object
#  9   Discount_offered     10996 non-null  float64
#  10  Weight_in_gms        10996 non-null  float64
#  11  Reached.on.Time_Y.N  10995 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                  4.0              2.0
# 1   2               F           Flight                  4.0              5.0
# 2   3               A           Flight                  2.0              2.0
# 3   4               B           Flight                  3.0              3.0
# 4   5               C           Flight                  2.0              2.0
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                177.0              3.0                low      F
# 1                216.0              2.0                low      M
# 2                183.0              4.0                low      M
# 3                176.0              4.0             medium      M
# 4                184.0              3.0             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %% [markdown]
# # mahsulotning discount berilishidan oldingi narxini topib olamiz

# %%
df['original_price']=(df['Cost_of_the_Product']/(100-df['Discount_offered']))*100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10995 non-null  object
#  3   Customer_care_calls  10995 non-null  float64
#  4   Customer_rating      10997 non-null  float64
#  5   Cost_of_the_Product  10996 non-null  float64
#  6   Prior_purchases      10996 non-null  float64
#  7   Product_importance   10996 non-null  object
#  8   Gender               10996 non-null  object
#  9   Discount_offered     10996 non-null  float64
#  10  Weight_in_gms        10996 non-null  float64
#  11  Reached.on.Time_Y.N  10995 non-null  float64
#  12  original_price       10993 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                  4.0              2.0
# 1   2               F           Flight                  4.0              5.0
# 2   3               A           Flight                  2.0              2.0
# 3   4               B           Flight                  3.0              3.0
# 4   5               C           Flight                  2.0              2.0
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                177.0              3.0                low      F
# 1                216.0              2.0                low      M
# 2                183.0              4.0                low      M
# 3                176.0              4.0             medium      M
# 4                184.0              3.0             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N  original_price
# ...

# %% [markdown]
# # grammdan kilogramga utqazib olamiz

# %%
df['Weight_in_kgs']=df['Weight_in_gms']/1000

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                  4.0              2.0
# 1   2               F           Flight                  4.0              5.0
# 2   3               A           Flight                  2.0              2.0
# 3   4               B           Flight                  3.0              3.0
# 4   5               C           Flight                  2.0              2.0
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                177.0              3.0                low      F
# 1                216.0              2.0                low      M
# 2                183.0              4.0                low      M
# 3                176.0              4.0             medium      M
# 4                184.0              3.0             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N  original_price  \
# ...
